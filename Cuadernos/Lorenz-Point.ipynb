# %% [markdown]
# ![Holi](https://wikimedia.org/api/rest_v1/media/math/render/svg/7928004d58943529a7be774575a62ca436a82a7f)

# %%
from P3Solver_EDOS import RK4
import matplotlib.pyplot as plt

### P EX

σ=10
ρ=28
β=8/3

## HP
#Modelo
f1=lambda t,x,y,z:σ*(y-x)
f2=lambda t,x,y,z:x*(ρ-z)-y
f3=lambda t,x,y,z:x*y-β*z

##CI
x0=2
y0=4
z0=-3

##Tiempito
T=[0,60]

##PN

n=1000000

# Sol Num
t,x,y,z=RK4(f1,f2,f3,x0,y0,z0,T,n)

# Gráficas
plt.figure(figsize=(15,7))

plt.plot(t,x)
plt.plot(t,y)
plt.plot(t,z)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(15,10))
plt.subplot(111,projection="3d")
plt.plot(x,y,z)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 28.0
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  # Desempaqueta el vector de estado
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # Derivadas

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure(figsize=(18,8))
plt.subplot(111,projection="3d")
plt.plot(states[:,0],states[:,1],states[:,2])
plt.show()
