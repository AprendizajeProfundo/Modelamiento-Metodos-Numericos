# %%
import matplotlib.pyplot as plt
from P2Solver_EDOS import *
##HP##

α=2/3
β=4/3
δ=1
γ=1


f1=lambda t,x,y:α*x-β*x*y
f2=lambda t,x,y:δ*x*y-γ*y

x0=0.9
y0=0.9
T=[1900,1921]

### NP ####
n=10**6

###### Solving Model ######

t,x,y=EulerM(f1,f2,x0,y0,T,n)

##### Graphics #####
plt.figure(figsize=(12,15))

plt.subplot(211)
plt.plot(t,x,t,y)

plt.subplot(212)
plt.plot(x,y)
plt.show()

# %%
time=range(1900,1921)
cone=[30,47.2,70.02,77.4,36.3,20.6,18.1,21.4,22,25.4,27.1,40.3,57,76.6,52.3,19.5,11.2,7.6,14.6,16.2,24.7]
zorr=[4,6.1,9.8,35.2,59.4,41.7,19,13,8.3,9.1,7.4,8,12.3,19.5,45.7,51.5,29.7,15.8,9.7,10.1,8.6]

plt.figure(figsize=(15,8))
plt.plot(time,cone,'b--.',time,zorr,'r--.')
plt.show()

# %%
##HP##

α=0.4
β=0.0195
δ=0.023
γ=0.8


f1=lambda t,x,y:α*x-β*x*y
f2=lambda t,x,y:δ*x*y-γ*y

x0=30
y0=4
T=[1900,1920]

### NP ####
n=100000

###### Solving Model ######

t,x,y=RK4(f1,f2,x0,y0,T,n)

plt.figure(figsize=(15,8))
plt.plot(t,x,'b-',t,y,'r-')
plt.plot(time,cone,'b.--',time,zorr,'r.--')
plt.show()

# %% [markdown]
# # Bibliografía
#
# [Lotka-Volterra (Wiki)](https://en.wikipedia.org/wiki/Lotka%E2%80%93Volterra_equations)
